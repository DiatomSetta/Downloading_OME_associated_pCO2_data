# %% [markdown]
# # Goal of file: Download OME relevant OA chemistry data

# %%
# %%bash
# # wget --show-progress <URL>
# wget --show-progress -P data/raw https://www.ncei.noaa.gov/archive/accession/download/304116
